# %%
# ======================================================================
# WBL 2026 – CANADA LEGAL ANSWER PIPELINE WITH EVALUATOR (GPT-5-MINI)
# ======================================================================

import os
import ssl
import certifi
import httpx
import re
import pandas as pd
import datetime
import time
import uuid
import json
from openai import OpenAI

# ----------------------------------------------------------------------
# CONFIGURATION
# ----------------------------------------------------------------------

MODEL = os.getenv("OPENAI_MODEL", "gpt-5-mini")
EVAL_MODEL = "gpt-5-mini"
API_KEY = "sk-"

MAX_OUTPUT_TOKENS = 4096
HTTP_TIMEOUT_SECS = 600
MAX_RETRIES = 3
BACKOFF_FACTOR = 2
CACHE_ENABLED = True

LOG_FILE = "run_log_WBL_CANADA.jsonl"
EVAL_LOG_FILE = "eval_log_WBL_CANADA.jsonl"

# ----------------------------------------------------------------------
# INITIALIZE CLIENT
# ----------------------------------------------------------------------

if not API_KEY or not API_KEY.startswith("sk-"):
    raise RuntimeError("Missing or invalid OPENAI_API_KEY. Please provide a valid key.")

_ctx = ssl.create_default_context(cafile=certifi.where())
_http = httpx.Client(verify=_ctx, timeout=HTTP_TIMEOUT_SECS, follow_redirects=True)
client = OpenAI(api_key=API_KEY, http_client=_http)

print("OpenAI client initialized (GPT-5-mini).")

# ----------------------------------------------------------------------
# PROMPT DEFINITIONS
# ----------------------------------------------------------------------

PROMPT_LEGAL = """
You are a senior legal expert specializing in Canada's labor, equality, and family law.
Your task is to answer questions for the World Bank’s Women, Business and the Law (WBL) 2026 project.

Pillar I: LEGAL FRAMEWORK
Interpret questions strictly in the context of binding national laws and regulations.
Base answers on codified legislation and subordinate regulations in force as of 1 September 2024.
Exclude customary or religious law unless it is codified in an act or regulation.
When applicable, prioritize federal or Ontario laws that apply in the main business city (Toronto).

Relevant sources include:
- Justice Laws Website (https://laws-lois.justice.gc.ca)
- Canada Labour Code
- Employment Equity Act
- Canadian Human Rights Act
- Pay Equity Act
- Employment Insurance Act
- Government of Canada and Ontario official portals

If an exact statute cannot be identified, infer the most probable answer using the Canadian legal system and mention this in the summary.

### Output Format (MUST FOLLOW EXACTLY)
ANSWER: <Yes/No/N/A | number | short phrase>
LAW/Website: <primary law or regulation>
LINK: <official URL(s)>
SUMMARY: <≤200 words summarizing reasoning and citing authoritative sources>
"""

PROMPT_POLICY = """
You are a senior policy and governance expert on gender equality and labor markets in Canada.
Your task is to answer questions for the World Bank’s Women, Business and the Law (WBL) 2026 project.

Pillar II: POLICY INSTRUMENTS
Interpret questions in the context of instruments that support the implementation of laws.
Include national and provincial policies, action plans, monitoring institutions, enforcement agencies,
access-to-justice measures, and government programs or data collection systems in place as of 1 September 2024.

Focus on:
- Federal and provincial ministries responsible for gender equality, labor, and employment.
- Operational government initiatives and datasets (e.g., Employment and Social Development Canada, Statistics Canada, Labour Program, Department for Women and Gender Equality).
- Public programs or registries, including enforcement or access mechanisms.

If no operational instrument is identified, state so clearly.

### Output Format (MUST FOLLOW EXACTLY)
ANSWER: <Yes/No/N/A | short phrase>
LAW/Website: <main institution, plan, or official instrument>
LINK: <official URL(s)>
SUMMARY: <≤200 words explaining the reasoning and describing relevant institutional instruments>
"""

def get_prompt_for_section(section):
    if "Policy Instrument" in str(section):
        return PROMPT_POLICY
    return PROMPT_LEGAL

# ----------------------------------------------------------------------
# SUPPORT FUNCTIONS
# ----------------------------------------------------------------------

cache = {}

def cached_call(key, fn):
    if CACHE_ENABLED and key in cache:
        return cache[key]
    value = fn()
    if CACHE_ENABLED:
        cache[key] = value
    return value

def exponential_backoff_retry(fn, max_retries=MAX_RETRIES, factor=BACKOFF_FACTOR):
    for attempt in range(max_retries):
        try:
            return fn()
        except Exception as e:
            wait = factor ** attempt
            print(f"Retry {attempt + 1}/{max_retries} after error: {e}. Waiting {wait}s.")
            time.sleep(wait)
    raise RuntimeError("Max retries exceeded.")

def calibrate_confidence(text):
    if not text:
        return 0.0
    text_lower = text.lower()
    if any(w in text_lower for w in ["clearly", "definitely", "explicitly", "yes"]):
        return 0.9
    if any(w in text_lower for w in ["likely", "generally", "appears", "probably"]):
        return 0.7
    if any(w in text_lower for w in ["unclear", "uncertain", "may", "not specified", "no information"]):
        return 0.4
    return 0.5

# ----------------------------------------------------------------------
# STAGE 1: PRIMARY ANSWER GENERATOR (A0)
# ----------------------------------------------------------------------

def get_legal_answer_canada(section, reference, question, economy="Canada"):
    cache_key = f"{economy}|{section}|{reference}"
    if CACHE_ENABLED and cache_key in cache:
        return cache[cache_key]

    system_prompt = get_prompt_for_section(section)
    user_prompt = f"""
Economy: {economy}
Section: {section}
Reference: {reference}

Question:
{question}

Task:
Provide the structured WBL-style response (ANSWER / LAW / LINK / SUMMARY)
based on applicable {economy} legal or policy frameworks.
"""

    def run_query():
        start_time = time.time()
        try:
            response = client.responses.create(
                model=MODEL,
                input=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt},
                ],
                store=True
            )
        except Exception as e:
            print(f"API call failed for {reference}: {e}")
            return None, 0
        latency = time.time() - start_time
        return response, latency

    response, latency = exponential_backoff_retry(run_query)
    if not response or not getattr(response, "output", None):
        print(f"Empty response object for {reference}.")
        return {
            "run_id": str(uuid.uuid4()),
            "economy": economy,
            "section": section,
            "reference": reference,
            "question": question,
            "answer": "",
            "law_website": "",
            "link": "",
            "summary": "[No output received from model]",
            "confidence": 0.0,
            "latency_seconds": round(latency, 2),
            "timestamp": datetime.datetime.now(datetime.timezone.utc).isoformat()
        }

    text_output = None
    for item in response.output or []:
        for part in getattr(item, "content", []) or []:
            text_val = getattr(part, "text", None) or part
            if isinstance(text_val, str) and text_val.strip():
                text_output = text_val.strip()
                break

    if not text_output:
        print(f"No text content returned for {reference}.")
        return {
            "run_id": str(uuid.uuid4()),
            "economy": economy,
            "section": section,
            "reference": reference,
            "question": question,
            "answer": "",
            "law_website": "",
            "link": "",
            "summary": "[Model returned no text]",
            "confidence": 0.0,
            "latency_seconds": round(latency, 2),
            "timestamp": datetime.datetime.now(datetime.timezone.utc).isoformat()
        }

    print(f"\n--- RAW MODEL OUTPUT ({reference}) ---\n{text_output[:400]}\n-------------------------\n")

    answer = re.search(r"ANSWER:\s*(.*)", text_output)
    law = re.search(r"LAW/Website:\s*(.*)", text_output)
    link = re.search(r"LINK:\s*(.*)", text_output)
    summary = re.search(r"SUMMARY:\s*(.*)", text_output, re.DOTALL)

    result = {
        "run_id": str(uuid.uuid4()),
        "economy": economy,
        "section": section,
        "reference": reference,
        "question": question,
        "answer": answer.group(1).strip() if answer else "",
        "law_website": law.group(1).strip() if law else "",
        "link": link.group(1).strip() if link else "",
        "summary": summary.group(1).strip() if summary else text_output,
        "confidence": calibrate_confidence(text_output),
        "latency_seconds": round(latency, 2),
        "timestamp": datetime.datetime.now(datetime.timezone.utc).isoformat()
    }

    cache[cache_key] = result
    with open(LOG_FILE, "a", encoding="utf-8") as logf:
        json.dump(result, logf)
        logf.write("\n")
    return result

# ----------------------------------------------------------------------
# STAGE 2: EVALUATOR (B5)
# ----------------------------------------------------------------------

def evaluate_answer(a0_result):
    economy = a0_result["economy"]
    reference = a0_result["reference"]

    EVAL_PROMPT = f"""
You are an independent senior legal evaluator for the World Bank’s Women, Business and the Law project.

Evaluate the correctness, legal validity, and completeness of the AI-generated answer (A0) below for {economy}.

Question: {a0_result["question"]}
A0 Answer: {a0_result["answer"]}
Law/Website: {a0_result["law_website"]}
Link: {a0_result["link"]}
Summary: {a0_result["summary"]}

Assess the legal reasoning and citations against authoritative Canadian sources.
If the cited laws are correct and current as of 1 September 2024, label as “Correct”.
Otherwise, classify the issue precisely.

### Output Format (STRICT)
VERDICT: Correct / Incorrect / Insufficient Evidence / Outdated Law
JUSTIFICATION: <≤100 words referencing specific sources or reasoning>
CORRECTED_ANSWER: <if applicable, otherwise blank>
CORRECTED_LAW/Website: <if applicable, otherwise blank>
CORRECTED_LINK: <if applicable, otherwise blank>
CORRECTED_SUMMARY: <if applicable, otherwise blank>
EVAL_CONFIDENCE: <float between 0 and 1>
"""

    start_time = time.time()
    try:
        response = client.responses.create(
            model=EVAL_MODEL,
            input=[
                {
                    "role": "system",
                    "content": "You are a legal evaluator who must return structured text following the output format exactly."
                },
                {"role": "user", "content": EVAL_PROMPT},
            ],
            store=True
        )
    except Exception as e:
        print(f"Evaluator API call failed for {reference}: {e}")
        return None

    latency = time.time() - start_time

    text_output = None
    if hasattr(response, "output_text") and response.output_text:
        text_output = response.output_text.strip()
    elif getattr(response, "output", None):
        for item in response.output or []:
            if isinstance(item, dict) and "content" in item:
                for part in item["content"]:
                    if isinstance(part, dict) and "text" in part:
                        text_output = part["text"].strip()
                        break
            elif hasattr(item, "content"):
                for part in getattr(item, "content", []):
                    text_val = getattr(part, "text", None)
                    if text_val:
                        text_output = text_val.strip()
                        break
            if text_output:
                break

    if not text_output:
        print(f"No evaluator text output for {reference}.")
        print(f"Raw evaluator response: {response}")
        return None

    print(f"\n--- RAW EVALUATOR OUTPUT ({reference}) ---\n{text_output[:400]}\n-------------------------\n")

    # Normalize for consistent parsing
    normalized = re.sub(r"\r", "", text_output)
    normalized = re.sub(r"\n+", "\n", normalized)
    normalized = re.sub(r"([A-Z_]+/Website:)", r"\n\1", normalized)
    normalized = re.sub(r"([A-Z_]+:)", r"\n\1", normalized)

    # Parse fields line-by-line for better precision
    def extract_field(label):
        pattern = rf"{label}:(.*?)(?=\n[A-Z_]+:|$)"
        match = re.search(pattern, normalized, re.DOTALL | re.IGNORECASE)
        return match.group(1).strip() if match else ""


    verdict = extract_field("VERDICT")
    justification = extract_field("JUSTIFICATION")
    corr_answer = extract_field("CORRECTED_ANSWER")
    corr_law = extract_field("CORRECTED_LAW/Website")
    corr_link = extract_field("CORRECTED_LINK")
    corr_summary = extract_field("CORRECTED_SUMMARY")
    eval_conf = extract_field("EVAL_CONFIDENCE")

    try:
        val = float(eval_conf)
    except:
        val = 0.5
    val = max(0.0, min(1.0, val))

    result = {
        "eval_run_id": str(uuid.uuid4()),
        "verdict": verdict,
        "justification": justification,
        "corrected_answer": corr_answer,
        "corrected_law_website": corr_law,
        "corrected_link": corr_link,
        "corrected_summary": corr_summary,
        "eval_confidence": val,
        "eval_latency_seconds": round(latency, 2),
        "eval_timestamp": datetime.datetime.now(datetime.timezone.utc).isoformat()
    }

    with open(EVAL_LOG_FILE, "a", encoding="utf-8") as f:
        json.dump(result, f)
        f.write("\n")
    return result

# ----------------------------------------------------------------------
# EXECUTION PIPELINE
# ----------------------------------------------------------------------

excel_path = r"C:\Users\wb611279\OneDrive - WBG\Desktop\AI Test\Clean_Fin_Extracted_WBL_Questions_Labor_FinalCleaned.xlsx"
df = pd.read_excel(excel_path)

for col in [
    "Economy", "ANSWER", "LAW/Website", "LINK", "SUMMARY", "CONFIDENCE",
    "LATENCY_SECONDS", "RUN_ID",
    "EVAL_VERDICT", "EVAL_JUSTIFICATION", "EVAL_CORRECTED_ANSWER",
    "EVAL_CORRECTED_LAW/Website", "EVAL_CORRECTED_LINK",
    "EVAL_CORRECTED_SUMMARY", "EVAL_CONFIDENCE", "EVAL_LATENCY_SECONDS"
]:
    if col not in df.columns:
        df[col] = ""

for idx, row in df.iterrows():
    section = str(row["Section"])
    reference = str(row["Reference"])
    question = str(row["Question"])
    if not question.strip():
        continue

    print(f"\nProcessing {reference} ({section[:40]})")

    a0 = get_legal_answer_canada(section, reference, question)
    if not a0:
        continue

    df.loc[idx, "Economy"] = a0["economy"]
    df.loc[idx, "ANSWER"] = a0["answer"]
    df.loc[idx, "LAW/Website"] = a0["law_website"]
    df.loc[idx, "LINK"] = a0["link"]
    df.loc[idx, "SUMMARY"] = a0["summary"]
    df.loc[idx, "CONFIDENCE"] = a0["confidence"]
    df.loc[idx, "LATENCY_SECONDS"] = a0["latency_seconds"]
    df.loc[idx, "RUN_ID"] = a0["run_id"]

    eval_result = evaluate_answer(a0)
    if eval_result:
        df.loc[idx, "EVAL_VERDICT"] = eval_result["verdict"]
        df.loc[idx, "EVAL_JUSTIFICATION"] = eval_result["justification"]
        df.loc[idx, "EVAL_CORRECTED_ANSWER"] = eval_result["corrected_answer"]
        df.loc[idx, "EVAL_CORRECTED_LAW/Website"] = eval_result["corrected_law_website"]
        df.loc[idx, "EVAL_CORRECTED_LINK"] = eval_result["corrected_link"]
        df.loc[idx, "EVAL_CORRECTED_SUMMARY"] = eval_result["corrected_summary"]
        df.loc[idx, "EVAL_CONFIDENCE"] = eval_result["eval_confidence"]
        df.loc[idx, "EVAL_LATENCY_SECONDS"] = eval_result["eval_latency_seconds"]

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
excel_out = excel_path.replace(".xlsx", f"_CANADA_with_Evals_{timestamp}.xlsx")
csv_out = excel_out.replace(".xlsx", ".csv")

df.to_excel(excel_out, index=False)
df.to_csv(csv_out, index=False, encoding="utf-8-sig")

print(f"\nCompleted. Results saved to:\n{excel_out}\n{csv_out}")
# Out:
# OpenAI client initialized (GPT-5-mini).
#
# Processing WBL_1_1 (Section 1. Work - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_1_1) ---
# ANSWER: Yes
# LAW/Website: Ontario Human Rights Code; Canada Human Rights Act (federal)
# LINK: https://www.ontario.ca/laws/statute/90h19
# https://laws-lois.justice.gc.ca/eng/acts/h-6/
# SUMMARY: Both provincial and federal human‑rights statutes prohibit discrimination in recruitment/employment on the bases asked. Ontario’s Human Rights Code (R.S.O. 1990, c. H.19) bars discrimination in employment becaus
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: Ontario Human Rights Code (R.S.O. 1990, c. H.19) expressly prohibits employment discrimination on the grounds of age, marital status and family status (commonly used to cover parental responsibilities). The Canada Human Rights Act likewise prohibits discrimination in federally regulated employment on grounds including age and marital status, and federal tribunals ha
# -------------------------
#
#
# Processing WBL_1_1_1 (Section 1. Work - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_1_1_1) ---
# ANSWER: Yes
# LAW/Website: Canadian Human Rights Act; Ontario Human Rights Code
# LINK: https://laws-lois.justice.gc.ca/eng/acts/h-6/ ; https://www.ontario.ca/laws/statute/90h19
# SUMMARY: Both federal and Ontario law prohibit discrimination in employment (including recruitment and hiring) on the ground of marital status. The Canadian Human Rights Act bars federally regulated employers and service provi
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_1_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: The Canadian Human Rights Act (R.S.C., 1985, c. H‑6) lists "marital status" among prohibited grounds of discrimination for federally regulated employment; the Ontario Human Rights Code (R.S.O. 1990, c. H.19), s.5(1), likewise expressly prohibits discrimination in employment and lists "marital status." Both statutes have been interpreted to cover recruitment and hiri
# -------------------------
#
#
# Processing WBL_1_1 (Section 1. Work - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_1_1) ---
# ANSWER: Yes
# LAW/Website: Canadian Human Rights Commission; Provincial and Territorial Human Rights Commissions and Tribunals (e.g., Ontario Human Rights Commission; British Columbia Human Rights Tribunal; Commission des droits de la personne et des droits de la jeunesse - Québec)
# LINK: https://www.chrc-ccdp.gc.ca/eng, https://laws-lois.justice.gc.ca/eng/acts/h-6/, https://www.chrt-tcdp.gc.ca/eng,
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: The answer accurately identifies the Canadian Human Rights Commission and Tribunal and provincial/territorial human rights commissions/tribunals (e.g., OHRC, BCHRT, CDPDJ) as the bodies that receive and process employment discrimination complaints. This is consistent with the Canadian Human Rights Act (R.S.C. 1985, c. H‑6) and provincial human rights legislation and
# -------------------------
#
#
# Processing WBL_1_2 (Section 1. Work - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_1_2) ---
# ANSWER: Yes
# LAW/Website: Employment and Social Development Canada – Employment Equity Program (with guidance/tools); Canadian Human Rights Commission guidance; Department for Women and Gender Equality (GBA+) and federal workplace inclusion initiatives
# LINK:
# - Employment Equity Program (ESDC): https://www.canada.ca/en/employment-social-development/services/employment-equity.html
# - Federal Contracto
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_1_2) ---
# VERDICT: Correct
#
# JUSTIFICATION: The A0 correctly identifies active federal awareness measures: Employment and Social Development Canada’s Employment Equity Program and Federal Contractors Program (Employment Equity Act obligations and employer tools), Canadian Human Rights Commission guidance on recruitment under the Canadian Human Rights Act, Women and Gender Equality Canada’s GBA+ guidance, and
# -------------------------
#
#
# Processing WBL_2_1 (Section 2. Pay - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_2_1) ---
# ANSWER: Yes
# LAW/Website: Pay Equity Act (federal); Canadian Human Rights Act; Ontario Pay Equity Act (provincial)
# LINK: https://www.canada.ca/en/employment-social-development/programs/pay-equity.html
# https://laws-lois.justice.gc.ca/eng/acts/h-6/
# https://www.ontario.ca/laws/statute/90p07
# SUMMARY: Canada’s statutory framework requires pay equity/equal remuneration for work of equal value. At the fed
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_2_1) ---
# VERDICT: Correct
# JUSTIFICATION: The federal Pay Equity Act (S.C. 2018, c. 25) imposes pay‑equity obligations on federally regulated employers and the federal public sector; the Canadian Human Rights Act prohibits sex‑based discrimination in employment terms including compensation; Ontario’s Pay Equity Act similarly mandates pay equity for covered employers. These citations accurately reflect bindi
# -------------------------
#
#
# Processing WBL_2_1_1 (Section 2. Pay - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_2_1_1) ---
# ANSWER: Yes
# LAW/Website: Pay Equity Act (Canada); Canadian Human Rights Act; Pay Equity Act, R.S.O. 1990, c. P.7 (Ontario)
# LINK:
# - Pay Equity Act (Canada): https://laws-lois.justice.gc.ca/eng/acts/P-4.2/
# - Canadian Human Rights Act: https://laws-lois.justice.gc.ca/eng/acts/H-6/
# - Pay Equity Act (Ontario): https://www.ontario.ca/laws/statute/90p07
# SUMMARY: Canada has binding equal-pay legislation.
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_2_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: The federal Pay Equity Act (S.C. 2018, c. 25; Justice Laws: Pay Equity Act) and the Canadian Human Rights Act prohibit sex-based pay discrimination and require pay‑equity measures for federally regulated employers; provinces (including Ontario’s Pay Equity Act, R.S.O. 1990, c. P.7) maintain their own statutory regimes. The A0 citations and legal characterisation are
# -------------------------
#
#
# Processing WBL_2_1 (Section 2. Pay - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_2_1) ---
# ANSWER: Yes
# LAW/Website: Statistics Canada — Labour Force Survey (LFS) and related labour surveys (SEPH, Job Vacancy and Wage Survey, Survey of Labour and Income Dynamics); Employment and Social Development Canada uses these data
# LINK:
# - Labour Force Survey (overview): https://www.statcan.gc.ca/eng/survey/household/3701
# - Labour statistics data/tables (searchable): https://www150.statcan.gc.ca/t1
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_2_1) ---
# VERDICT: Correct
# JUSTIFICATION: Statistics Canada’s Labour Force Survey routinely publishes anonymized, sex-disaggregated employment and earnings statistics by industry (NAICS) on a monthly/annual basis; complementary Statistics Canada products (SEPH, Job Vacancy and Wage Survey, longitudinal income surveys) supply industry-level payroll/vacancy/earnings data used by federal departments (e.g., Emp
# -------------------------
#
#
# Processing WBL_2_1_1 (Section 2. Pay - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_2_1_1) ---
# ANSWER: Yes
# LAW/Website: Statistics Canada — Labour Force Survey (LFS) data tables; Employment and Social Development Canada — Labour Market Information (uses LFS)
# LINK: https://www.statcan.gc.ca/en/survey/household/3701
# https://www.canada.ca/en/employment-social-development/programs/labour-market-information.html
# https://www150.statcan.gc.ca/t1/tbl1/en/subjects/Labour%20and%20employment
# SUMMARY:
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_2_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: Statistics Canada’s Labour Force Survey (LFS) routinely publishes monthly and annual employment statistics by industry (NAICS) disaggregated by sex at national and provincial/territorial levels; microdata (PUMFs, RDC access) are available. Employment and Social Development Canada’s Labour Market Information portal draws on LFS and releases sex-by-industry labour sta
# -------------------------
#
#
# Processing WBL_3_1 (Section 3. Parenthood - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_3_1) ---
# ANSWER: Yes
# LAW/Website: Employment Insurance Act (federal); Quebec Parental Insurance Plan Act (provincial, for Quebec)
# LINK: https://laws-lois.justice.gc.ca/eng/acts/E-5.6/
# https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html
# https://www.legisquebec.gouv.qc.ca/en/document/cs/R-20.1
# https://www.quebec.ca/en/family-and-support-for-individuals/parents/quebec-parental-insur
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_1) ---
# VERDICT: Correct
# JUSTIFICATION: The AI answer correctly identifies federal paid maternity/parental benefits under the Employment Insurance Act (maternity up to 15 weeks; parental benefits with standard and extended options) and Quebec’s alternative Parental Insurance Plan. These are the primary statutory paid-leave schemes for mothers in Canada; provincial employment standards generally provide un
# -------------------------
#
#
# Processing WBL_3_1_1 (Section 3. Parenthood - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_3_1_1) ---
# ANSWER: 105 days
# LAW/Website: Employment Insurance Act; Employment Insurance Regulations (federal); Canada Labour Code (job‑protection context)
# LINK: https://laws-lois.justice.gc.ca/eng/acts/E-5.6/; https://laws-lois.justice.gc.ca/eng/regulations/SOR-96-332/; https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html; https://laws-lois.justice.gc.ca/eng/acts/L-2/
# SUMMARY: Under Canad
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: The Employment Insurance Act and Regulations provide maternity benefits for up to 15 weeks (15 × 7 = 105 days) as publicly funded income‑replacement (see Employment Insurance Act; EI Regulations; Government of Canada EI maternity benefits page). The Canada Labour Code and provincial employment‑standards laws provide unpaid, job‑protected maternity leave (federal Cod
# -------------------------
#
#
# Processing WBL_3_1_2 (Section 3. Parenthood - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_3_1_2) ---
# ANSWER: 280 days (standard parental benefits) or 483 days (extended parental benefits)
# LAW/Website: Employment Insurance Act; Government of Canada — Maternity and parental benefits (EI)
# LINK: https://laws-lois.justice.gc.ca/eng/acts/E-5.6/ ; https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html
# SUMMARY: Canada provides paid parental benefits through the federal Employment Insura
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_1_2) ---
# VERDICT: Correct
# JUSTIFICATION: The figures match federal EI rules as set out in the Employment Insurance framework and the Government of Canada “Maternity and parental benefits” guidance: parents may share up to 40 weeks (standard) or 69 weeks (extended) of parental benefits (40×7=280 days; 69×7=483 days). Limits apply where a parent also receives maternity benefits (max 35 weeks standard / 61 we
# -------------------------
#
#
# Processing WBL_3_1_3 (Section 3. Parenthood - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_3_1_3) ---
# ANSWER: 0
# LAW/Website: Employment Insurance Act (R.S.C., 1985, c. E-5) and Government of Canada — EI maternity and parental benefits guidance
# LINK: https://laws-lois.justice.gc.ca/eng/acts/E-5/; https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html
# SUMMARY: Under Canadian federal law, paid benefits reserved specifically for the birth mother are provided as "maternity benefits" (
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_1_3) ---
# VERDICT: Correct
# JUSTIFICATION: The Employment Insurance Act and Government of Canada guidance distinguish maternity benefits (up to 15 weeks reserved for the birth mother) from parental benefits. Parental benefits are shared between parents (standard up to 40 weeks, one parent limited to 35; extended up to 69 weeks, one parent limited to 61), but no parental-benefit days are legally reserved spec
# -------------------------
#
#
# Processing WBL_3_1 (Section 3. Parenthood - Policy Instrumen)
#
# --- RAW MODEL OUTPUT (WBL_3_1) ---
# ANSWER: Yes
# LAW/Website: Employment and Social Development Canada / Service Canada — Employment Insurance (EI) maternity and parental benefits application; (Quebec exception: Quebec Parental Insurance Plan (QPIP) administered provincially)
# LINK: https://www.canada.ca/en/services/benefits/ei/ei-apply.html , https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html , https://www.quebe
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_1) ---
# VERDICT: Correct
# JUSTIFICATION: Service Canada’s “Apply for Employment Insurance” / My Service Canada Account is the single federal application for EI maternity and parental benefits (Employment Insurance program) and covers both benefit types (see Canada.ca EI application pages). Quebec is a statutory exception — the Quebec Parental Insurance Plan is administered provincially and has its own appl
# -------------------------
#
#
# Processing WBL_3_2 (Section 3. Parenthood - Policy Instrumen)
#
# --- RAW MODEL OUTPUT (WBL_3_2) ---
# ANSWER: Yes
# LAW/Website: Quebec Parental Insurance Plan (Retraite Québec) — plus federal EI parental benefits (Service Canada / Employment and Social Development Canada)
# LINK: https://www.canada.ca/en/services/benefits/ei/ei-maternity-parental.html
# https://www.quebec.ca/en/family-and-support-for-caregivers/parental-insurance/
# SUMMARY: Canada’s federal Employment Insurance (EI) parental benefit fra
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_3_2) ---
# VERDICT: Correct
# JUSTIFICATION: A0 accurately notes that federal EI parental benefits are shareable and do not create a nationwide non‑transferable “father’s quota” (see Service Canada, EI maternity and parental benefits). It also correctly identifies Quebec’s Parental Insurance Plan (Retraite Québec/QPIP) as providing father/partner‑specific, non‑transferable paternity and reserved parental weeks
# -------------------------
#
#
# Processing WBL_4_1_1 (Section 4. Childcare - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_4_1_1) ---
# ANSWER: Yes
# LAW/Website: Child Care and Early Years Act, 2014 (Ontario); Canada-wide Early Learning and Child Care (ELCC) agreements (federal program framework)
# LINK: https://www.ontario.ca/laws/statute/14c11
# https://www.canada.ca/en/employment-social-development/programs/early-learning-child-care.html
# SUMMARY: Ontario’s Child Care and Early Years Act, 2014 (CCEYA) establishes a statutory framewor
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_4_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: The CCEYA (Child Care and Early Years Act, 2014) is the Ontario statute creating a licensing/funding/administration framework (Minister and municipal service system managers) for publicly funded child care (see Ontario e-Laws). At the federal level, the Canada-wide Early Learning and Child Care (ELCC) agreements (administered by ESDC/Employment and Social Developmen
# -------------------------
#
#
# Processing WBL_4_1_1 (Section 4. Childcare - Legal Framework)
#
# --- RAW EVALUATOR OUTPUT (WBL_4_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: Ontario’s Child Care and Early Years Act, 2014 (S.O. 2014, c. 11) establishes a statutory framework for licensed, publicly funded child care and assigns roles to the Minister and service system managers. The federal Canada-wide Early Learning and Child Care (ELCC) initiative (bilateral agreements administered by Employment and Social Development Canada) provides bin
# -------------------------
#
#
# Processing WBL_4_1 (Section 4. Childcare - Policy Instrument)
#
# --- RAW MODEL OUTPUT (WBL_4_1) ---
# ANSWER: Yes
# LAW/Website: Provincial and territorial licensed child-care provider registries (linked from the Government of Canada child-care portal)
# LINK: https://www.canada.ca/en/employment-social-development/programs/early-learning-child-care.html
# https://www.ontario.ca/page/find-licensed-child-care
# https://www2.gov.bc.ca/gov/content/family-social-supports/caring-for-young-children/child-care-fi
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_4_1) ---
# VERDICT: Correct
# JUSTIFICATION: Child care is provincially/territorially regulated in Canada and the federal Early Learning and Child Care portal links to provincial/territorial provider registries. Provinces/territories maintain public searches/directories (e.g. Ontario “Find child care” https://www.ontario.ca/page/find-child-care; Alberta “Finding child care” https://www.alberta.ca/finding-child
# -------------------------
#
#
# Processing WBL_4_2 (Section 4. Childcare - Policy Instrument)
#
# --- RAW MODEL OUTPUT (WBL_4_2) ---
# ANSWER: Yes
#
# LAW/Website: Canada-wide Early Learning and Child Care (CWELCC) system (federal-provincial/territorial agreements) — administered by Employment and Social Development Canada (federal) and by provincial/territorial ministries that operate childcare subsidy programs
#
# LINK:
# - Federal CWELCC overview: https://www.canada.ca/en/employment-social-development/programs/early-learning-child-ca
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_4_2) ---
# VERDICT: Correct
#
# JUSTIFICATION: Federal CWELCC provides funding but directs parents to provincial/territorial subsidy schemes; provinces/territories publish operational application procedures and portals (e.g., Ontario: "Apply for a child care fee subsidy"; BC: child care fee subsidy; Quebec: services de garde subventionnés). Canada Child Benefit (CRA) has its own established application/registra
# -------------------------
#
#
# Processing WBL_4_2 (Section 4. Childcare - Policy Instrument)
#
# --- RAW EVALUATOR OUTPUT (WBL_4_2) ---
# VERDICT: Correct
#
# JUSTIFICATION: The CWELCC framework (Employment and Social Development Canada) provides federal funding and directs parents to provincial/territorial subsidy programs; provinces/territories operate and publish specific application procedures and portals (e.g., Ontario "Child Care Fee Subsidy" — Ontario Ministry of Education; British Columbia "Child Care Subsidy" — gov.bc.ca; Québ
# -------------------------
#
#
# Processing WBL_4_2 (Section 4. Childcare - Policy Instrument)
#
# --- RAW EVALUATOR OUTPUT (WBL_4_2) ---
# VERDICT: Correct
#
# JUSTIFICATION: The CWELCC is a federal-provincial/territorial funding framework (administered at federal level by ESDC) that directs parents to provincially/territorially administered childcare subsidy application procedures and portals; provinces/territories publish operational application guidance. The Canada Child Benefit (CRA) also has an established application process. See
# -------------------------
#
#
# Processing WBL_5_1 (Section 5. Pension - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_5_1) ---
# ANSWER: Yes
# LAW/Website: Canada Pension Plan; Old Age Security Act; Canadian Human Rights Act (and Ontario Human Rights Code / Ontario Pension Benefits Act as applicable)
# LINK: https://laws-lois.justice.gc.ca/eng/acts/C-8/ (Canada Pension Plan)
# https://laws-lois.justice.gc.ca/eng/acts/O-9/ (Old Age Security Act)
# https://laws-lois.justice.gc.ca/eng/acts/H-6/ (Canadian Human Rights Act)
# https://www.
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_5_1) ---
# VERDICT: Correct
# JUSTIFICATION: Federal law treats retirement ages identically by sex: the Canada Pension Plan provides a standard retirement age of 65 (early from 60; defer/boost to 70) and Old Age Security is payable at 65. Federal and provincial human-rights and pension statutes prohibit sex-based differentiation (Canada Pension Plan Act; Old Age Security Act; Canadian Human Rights Act; e.g. On
# -------------------------
#
#
# Processing WBL_5_1_1 (Section 5. Pension - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_5_1_1) ---
# ANSWER: 65
# LAW/Website: Canada Pension Plan; Old Age Security Act
# LINK: https://laws-lois.justice.gc.ca/eng/acts/C-8/ ; https://laws-lois.justice.gc.ca/eng/acts/O-9/ ; https://www.canada.ca/en/services/benefits/publicpensions/cpp/cpp-benefit/retirement-pension.html ; https://www.canada.ca/en/services/benefits/publicpensions/old-age-security.html
# SUMMARY: Under federal pension law, both women and m
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_5_1_1) ---
# VERDICT: Correct
# JUSTIFICATION: Federal law (Canada Pension Plan and Old Age Security Act) provides an unreduced retirement pension at age 65 for all beneficiaries, with options to take reduced benefits from age 60 or defer to age 70 for an increased pension (CPP and OAS guidance from Government of Canada). There is no different statutory full-benefit age for women. (Quebec's comparable Quebec Pen
# -------------------------
#
#
# Processing WBL_5_1 (Section 5. Pension - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_5_1) ---
# ANSWER: Yes
# LAW/Website: Canada Pension Plan — child‑rearing provision; Pension income‑splitting (Income Tax Act / CRA); provincial pension‑division rules on relationship breakdown
# LINK:
# - Canada Pension Plan — child‑rearing provision (Service Canada): https://www.canada.ca/en/services/benefits/publicpensions/cpp/cpp-benefit/child-rearing-provision.html
# - Canada Pension Plan (general): https://ww
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_5_1) ---
# VERDICT: Correct
# JUSTIFICATION: The A0 answer correctly identifies operative instruments as of 1 Sept 2024: the CPP child‑rearing provision (Service Canada) and Quebec QPP analogue; federal pension‑income splitting under the Income Tax Act/CRA; provincial/territorial pension‑division regimes on relationship breakdown; and the 2019 CPP enhancement. These measures legally operate to raise or protect
# -------------------------
#
#
# Processing WBL_5_2 (Section 5. Pension - Policy Instruments)
#
# --- RAW MODEL OUTPUT (WBL_5_2) ---
# ANSWER: Yes
# LAW/Website: Service Canada (CPP/OAS decisions) and Social Security Tribunal; provincial pension regulators (e.g., Régie des rentes du Québec; FSRA Ontario)
# LINK: https://www.canada.ca/en/services/benefits/publicpensions/cpp/appeal.html, https://www.sst-tss.gc.ca/en, https://www.fct-cf.gc.ca/en, https://www.rrq.gouv.qc.ca/en, https://www.fsrao.ca/consumers/pensions/making-complaint-abo
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_5_2) ---
# VERDICT: Correct
# JUSTIFICATION: Service Canada provides reconsideration and appeals for CPP/OAS decisions (Canada.ca), appeals are heard by the Social Security Tribunal (General/Appeal Divisions) with judicial review to the Federal Court, and provincial regulators (e.g., FSRA) and Quebec authorities (Régie/Retraite Québec) have statutory complaint/review routes for pension plans; federally-regulat
# -------------------------
#
#
# Processing WBL_6_1 (Section 6. Procurement - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_6_1) ---
# ANSWER: 00: No
# LAW/Website: Financial Administration Act; Government Contracts Regulations; Treasury Board Contracting Policy; Treasury Board Policy on Gender‑Based Analysis Plus; Public Services and Procurement Canada (Inclusive Procurement) materials
# LINK: https://laws-lois.justice.gc.ca/eng/acts/F-11/
# https://laws-lois.justice.gc.ca/eng/regulations/SOR-87-402/
# https://www.tbs-sct.gc.ca/pol/do
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_6_1) ---
# VERDICT: Correct
# JUSTIFICATION: Federal procurement is governed by the Financial Administration Act and the Government Contracts Regulations and implemented via Treasury Board contracting policy. Treasury Board’s Contracting Policy and the Policy on Gender‑Based Analysis Plus require GBA+ and endorse inclusive procurement but do not create statutory set‑asides, quotas, or legally enforceable procu
# -------------------------
#
#
# Processing WBL_6_3 (Section 6. Procurement - Legal Framework)
#
# --- RAW MODEL OUTPUT (WBL_6_3) ---
# ANSWER: 01: Yes
# LAW/Website: Financial Administration Act; Treasury Board Contracting Policy; Public Services and Procurement Canada (federal procurement framework)
# LINK: https://laws-lois.justice.gc.ca/eng/acts/F-11/
# https://www.tbs-sct.gc.ca/pol/doc-eng.aspx?id=14494
# https://www.tpsgc-pwgsc.gc.ca/app-acq/index-eng.html
# SUMMARY: Enforcement of Canada’s federal procurement framework faces several
# -------------------------
#
#
# --- RAW EVALUATOR OUTPUT (WBL_6_3) ---
# VERDICT: Correct
# JUSTIFICATION: The cited primary statute (Financial Administration Act, R.S.C. 1985, c. F-11) and institutional frameworks (Treasury Board contracting policy; Public Services and Procurement Canada procurement framework) are correctly identified and current as of 1 Sept 2024. The practical enforcement issues cited (decentralized contracting authority, non‑competitive/sole‑source a
# -------------------------
#
#
# Completed. Results saved to:
# C:\Users\wb611279\OneDrive - WBG\Desktop\AI Test\Clean_Fin_Extracted_WBL_Questions_Labor_FinalCleaned_CANADA_with_Evals_20251104_151351.xlsx
# C:\Users\wb611279\OneDrive - WBG\Desktop\AI Test\Clean_Fin_Extracted_WBL_Questions_Labor_FinalCleaned_CANADA_with_Evals_20251104_151351.csv
